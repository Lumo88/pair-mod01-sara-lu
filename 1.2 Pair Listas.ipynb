# %%
#1. Duplicar lista

lista = [2,4,6,8]

listaDuplicada = lista.copy()

lista.extend(lista)
print(lista)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %%
#2 Combinar dos listas

lista1 = [1,2,3]
lista2 = [4,5,6]

lista1.extend(lista2)
#lista3 = [lista1+lista2]

print(lista1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#3 Calcula la suma de una lista de números

lista4 = [1,2,3]

print("La longitud es", len(lista4))

print("La suma del contenido de la lista es",lista4[0]+lista4[1]+lista4[2])
# Out:
# La longitud es 3
# La suma del contenido de la lista es 6

# %%
#4 Encontrar el máximo de una lista

print("El máximo de la lista4 es", max(lista4))
# Out:
# El máximo de la lista4 es 3

# %%
#5 Calcular la longitud de la lista

print("La longitud de la lista4 es", len(lista4))
# Out:
# La longitud de la lista4 es 3

# %%
#6 Encontrar el índice de un elemento de una lista

print(lista1)
#Valor objetivo = 4

print("El numero 4 está en la posición",lista1.index(4))
# Out:
# [1, 2, 3, 4, 5, 6]
# El numero 4 está en la posición 3

# %%
#7 Contar las ocurrencias de un elemento en una lista

lista5 = [2,3,5,62,5,7,23,5,7,8,5,9,5] #repetimos el 5

print("El numero 5 está repetido",lista5.count(5), "veces")
# Out:
# El numero 5 está repetido 5 veces

# %%
#8 Crea una lista que contenga los elementos desde el 2 al 5.

lista6 =[1,2,5,9,24,50]

lista5 = lista6[1:5]

print(lista5)
# Out:
# [2, 5, 9, 24]

# %%
#9 Obtener el ultimo elemento de una lista

#lista5[3]
lista5[-1]
# Out:
# 24

# %%
#10 Obtener el ultimo objeto de la lista

# %%
#11 Obtener una sublista de una lista.

lista
